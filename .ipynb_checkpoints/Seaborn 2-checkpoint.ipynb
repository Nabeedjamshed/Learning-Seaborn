# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = np.linspace(1,5,12).reshape(3,4)
df
# Out:
# array([[1.        , 1.36363636, 1.72727273, 2.09090909],
#        [2.45454545, 2.81818182, 3.18181818, 3.54545455],
#        [3.90909091, 4.27272727, 4.63636364, 5.        ]])

# %%
sns.heatmap(df) # In heatmap we represent 2D data, use heatmap mostly for feature engineering
# Out:
# <Axes: >

# %%
globaldf = pd.read_csv(r"D:\Jupyter\Excel\global_warming.csv")
globaldf.head(3)
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0   United States          USA  CO2 emissions (metric tons per capita)
# 1  United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2           India          IND  CO2 emissions (metric tons per capita)
#
#    Indicator Code       2000       2001       2002       2003       2004  \
# 0  EN.ATM.CO2E.PC  20.178751  19.636505  19.613404  19.564105  19.658371
# 1  EN.ATM.CO2E.PC   9.199549   9.233175   8.904123   9.053278   8.989140
# 2  EN.ATM.CO2E.PC   0.979870   0.971698   0.967381   0.992392   1.025028
#
#         2005       2006       2007       2008       2009       2010  \
# 0  19.591885  19.094067  19.217898  18.461764  17.157738  17.442862
# 1   8.982939   8.898710   8.617164   8.424424   7.574622   7.857836
# 2   1.068563   1.121982   1.193210   1.310098   1.431844   1.397009
#
#         2011       2012       2013       2014
# 0  16.976957  16.310471  16.323477  16.502837
# ...

# %%
# drop categorical data bcz heatmap numerical data leta hai, country ko drop nhi kya usse index bnadya take pta chale konse country ka data hai
globaldf = globaldf.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code']).set_index('Country Name')
globaldf
# Out:
#                          2000       2001       2002       2003       2004  \
# Country Name
# United States       20.178751  19.636505  19.613404  19.564105  19.658371
# United Kingdom       9.199549   9.233175   8.904123   9.053278   8.989140
# India                0.979870   0.971698   0.967381   0.992392   1.025028
# China                2.696862   2.742121   3.007083   3.524074   4.037991
# Russian Federation  10.627121  10.669603  10.715901  11.090647  11.120627
# Australia           17.200610  16.733367  17.370452  16.901959  17.026515
# France               5.946665   6.153061   6.068664   6.115998   6.120079
# Germany             10.095640  10.366287  10.058673   9.969355   9.898682
# Canada              17.367115  16.985030  16.559378  17.461199  17.258911
# Brazil               1.871118   1.898354   1.844380   1.762482   1.828672
# Argentina            3.835574   3.568600   3.291548   3.525584   4.069058
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(globaldf, vmin=0, vmax=21) #vmin and vmax se values ko set krskte ke kha se kha tk ka data show krao
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(globaldf, vmin=0, vmax=21, cmap='coolwarm') #coolwarm is more good to understand the data
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(globaldf, vmin=0, vmax=21, cmap='coolwarm', annot=True) #annot se table mai jo data likha hai uski value bhi aajati ahi
# Out:
# <Axes: ylabel='Country Name'>

# %%
df
# Out:
# array([[1.        , 1.36363636, 1.72727273, 2.09090909],
#        [2.45454545, 2.81818182, 3.18181818, 3.54545455],
#        [3.90909091, 4.27272727, 4.63636364, 5.        ]])

# %%
names = np.array([['a1','a2','a3','a4'],['a5','a6','a7','a8'],['a9','a10','a11','a12']])
sns.heatmap(df, cmap='viridis',annot=names, fmt='s') #by using annot wo values bhi dal skte hai or apni marzi se bhi values dalskte hai, fmt mai array ki type likhte hai s for string
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,9))
sns.heatmap(globaldf, vmin=0, vmax=21, cmap='coolwarm', annot=True,linewidths=1,linecolor='k') # linewidths=1,linecolor='k' this parameters set the line between the boxes and set ther colors
# Out:
# <Axes: ylabel='Country Name'>
